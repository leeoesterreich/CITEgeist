# %% [markdown]
# # Vignette 1: Biopsy Heterogeneity (Canonical v5)
#
# Canonical reproducibility wrapper notebook for manuscript submission.

# %%
CITEGEIST_DATA_ROOT = "/path/to/GEO/processed_files"
CITEGEIST_OUTPUT_ROOT = "/path/to/output"
CITEGEIST_LICENSE_FILE = "/path/to/gurobi.lic"

# %% [markdown]
# Legacy source notebook: `examples/vignette_1_biopsy_heterogeneity.ipynb`
#
# Use `python -m repro.cli.run_vignette --id 1` as the canonical entrypoint.
