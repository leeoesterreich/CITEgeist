# %% [markdown]
# # Vignette 4: Interoperability + COMMOT (Canonical v5)
#
# Submission-ready replacement for the prior exploratory external-tools notebook.

# %%
CITEGEIST_DATA_ROOT = "/path/to/GEO/processed_files"
CITEGEIST_OUTPUT_ROOT = "/path/to/output"
CITEGEIST_LICENSE_FILE = "/path/to/gurobi.lic"

# %% [markdown]
# Legacy exploratory notebook: `examples/vignette_4_external_tools.ipynb`
#
# Use `python -m repro.cli.run_vignette --id 4` as the canonical entrypoint.
