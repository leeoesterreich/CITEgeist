# %% [markdown]
# # Vignette 2: ESR1 D538G Surgical Analysis (Canonical v5)
#
# Canonical reproducibility wrapper notebook for manuscript submission.

# %%
CITEGEIST_DATA_ROOT = "/path/to/GEO/processed_files"
CITEGEIST_OUTPUT_ROOT = "/path/to/output"
CITEGEIST_LICENSE_FILE = "/path/to/gurobi.lic"

# %% [markdown]
# Legacy source notebook: `examples/vignette_2_surgical_d538g.ipynb`
#
# Use `python -m repro.cli.run_vignette --id 2` as the canonical entrypoint.
